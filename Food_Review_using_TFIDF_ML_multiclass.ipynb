# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import keras
from keras.models import Sequential
from keras import layers
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils.vis_utils import plot_model
from warnings import filterwarnings
filterwarnings('ignore')
import string
import os

# %%
# !pip install nltk
import nltk

nltk.download('all')
# Out:
# Requirement already satisfied: nltk in c:\users\hkmeh\anaconda3\envs\tf-nlp\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\hkmeh\anaconda3\envs\tf-nlp\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\hkmeh\appdata\roaming\python\python39\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hkmeh\anaconda3\envs\tf-nlp\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\hkmeh\anaconda3\envs\tf-nlp\lib\site-packages (from nltk) (4.66.1)
# Requirement already satisfied: colorama in c:\users\hkmeh\anaconda3\envs\tf-nlp\lib\site-packages (from click->nltk) (0.4.6)
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\hkmeh\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
file="Reviews.csv"
import pandas as pd
data= pd.read_csv(file)
print(data.shape)
# Out:
# (334119, 31)

# %%
data.head()
# Out:
#    Unnamed: 0  ï»¿                                  uuid  \
# 0           0    0  68e8f769-a0f0-460c-bfb9-16662fcc1e17
# 1           1    1  706a1e43-7475-4d7f-8488-cb8ed2ea8991
# 2           2    2  16cd99a3-7295-432e-b193-1551df62d255
# 3           3    3  61a9fdf3-ad6b-4d23-9436-1f2f596bbcff
# 4           4    4  a7835cdf-2c1f-4cf0-b9d5-2777d904d746
#
#               createdAt             updatedAt  \
# 0  2023-11-02T06:48:08Z  2023-11-02T06:48:08Z
# 1  2023-10-27T07:35:53Z  2023-10-27T07:35:53Z
# 2  2023-10-25T18:09:17Z  2023-10-25T18:09:17Z
# 3  2023-10-25T07:48:39Z  2023-10-25T07:48:39Z
# 4  2023-10-15T13:37:20Z  2023-10-15T13:37:20Z
#
#                                                 text  isAnonymous  \
# 0                              too much small amount        False
# 1                               very small in amount        False
# 2  food average but their desert booter halwa and...        False
# 3                                    fresh and tasty        False
# 4                      everything i ordered was good        False
#
#   reviewerName reviewerId  ratings_overall  ...  longitude primary_cuisine  \
# 0         MOON   bdaclwhn                2  ...   90.39168           Curry
# 1         MOON   bdaclwhn                2  ...   90.39168           Curry
# 2       SALMAN   bdjrt0zq                3  ...   90.39168           Curry
# 3        GOLAM   b6hrp8of                5  ...   90.39168           Curry
# 4      FERZANA   bddrkjrd                4  ...   90.39168           Curry
#
#   primary_cuisine_id                                          cuisines  \
# 0                195  ['Curry', 'Rice Dishes', 'Bangladeshi', 'Asian']
# 1                195  ['Curry', 'Rice Dishes', 'Bangladeshi', 'Asian']
# 2                195  ['Curry', 'Rice Dishes', 'Bangladeshi', 'Asian']
# 3                195  ['Curry', 'Rice Dishes', 'Bangladeshi', 'Asian']
# 4                195  ['Curry', 'Rice Dishes', 'Bangladeshi', 'Asian']
#
#    review_number restaurant_overall_rating  \
# 0            146                       3.7
# 1            146                       3.7
# 2            146                       3.7
# 3            146                       3.7
# 4            146                       3.7
#
#                                           hero_image  \
# 0  https://images.deliveryhero.io/image/fd-bd/LH/...
# 1  https://images.deliveryhero.io/image/fd-bd/LH/...
# 2  https://images.deliveryhero.io/image/fd-bd/LH/...
# 3  https://images.deliveryhero.io/image/fd-bd/LH/...
# 4  https://images.deliveryhero.io/image/fd-bd/LH/...
#
#                                   hero_listing_image  \
# 0  https://images.deliveryhero.io/image/fd-bd/LH/...
# 1  https://images.deliveryhero.io/image/fd-bd/LH/...
# 2  https://images.deliveryhero.io/image/fd-bd/LH/...
# 3  https://images.deliveryhero.io/image/fd-bd/LH/...
# 4  https://images.deliveryhero.io/image/fd-bd/LH/...
#
#                        vertical_type_ids  \
# 0  ['restaurants', 'home_based_kitchen']
# 1  ['restaurants', 'home_based_kitchen']
# 2  ['restaurants', 'home_based_kitchen']
# 3  ['restaurants', 'home_based_kitchen']
# 4  ['restaurants', 'home_based_kitchen']
#
#                                             web_path
# 0  https://foodpanda.com.bd/restaurant/a02g/mahis...
# 1  https://foodpanda.com.bd/restaurant/a02g/mahis...
# 2  https://foodpanda.com.bd/restaurant/a02g/mahis...
# 3  https://foodpanda.com.bd/restaurant/a02g/mahis...
# 4  https://foodpanda.com.bd/restaurant/a02g/mahis...
#
# [5 rows x 31 columns]

# %%
data.loc[1:10, ['text','reviewerName', 'ratings_overall','labels']]
# Out:
#                                                  text reviewerName  \
# 1                                very small in amount         MOON
# 2   food average but their desert booter halwa and...       SALMAN
# 3                                     fresh and tasty        GOLAM
# 4                       everything i ordered was good      FERZANA
# 5   kalo jira vhorta balu vhorta not recommended b...      FERZANA
# 6   quantity of dal should be little more otherwis...      FERZANA
# 7   beef was too poor in size quantity aganist pri...        DEDAR
# 8   chicken was not up to the mark and lotpoti was...     IFTEKHER
# 9                    lot of sand in kali jeers bortha     MOHAMMAD
# 10                                                bad     MOHAMMAD
#
#     ratings_overall  labels
# 1                 2       1
# 2                 3       2
# 3                 5       3
# 4                 4       3
# 5                 1       1
# 6                 4       3
# 7                 3       2
# 8                 5       3
# 9                 4       3
# 10                1       1

# %%
data['ratings_overall'].value_counts()
# Out:
# ratings_overall
# 1    127409
# 5     94199
# 4     39330
# 3     39315
# 2     33866
# Name: count, dtype: int64

# %%
data['ratings_overall'].unique()
# Out:
# array([2, 3, 5, 4, 1], dtype=int64)

# %%
data.iloc[0:16]['text']
# Out:
# 0                                 too much small amount
# 1                                  very small in amount
# 2     food average but their desert booter halwa and...
# 3                                       fresh and tasty
# 4                         everything i ordered was good
# 5     kalo jira vhorta balu vhorta not recommended b...
# 6     quantity of dal should be little more otherwis...
# 7     beef was too poor in size quantity aganist pri...
# 8     chicken was not up to the mark and lotpoti was...
# 9                      lot of sand in kali jeers bortha
# 10                                                  bad
# 11    very good food i chose this home kitchen rando...
# 12    honestly eating today s beef ribs and dal felt...
# 13    i ate good food after a long time the food was...
# 14           really good clean tasting will order again
# 15                           too spicy with dry chilli
# Name: text, dtype: object

# %%
import re
import nltk
stemmer = nltk.SnowballStemmer("english")
from nltk.corpus import stopwords
import string
stopword=set(stopwords.words('english'))

# %% [markdown]
# # Text preprocessing

# %%
def clean_text(text):
    text = text.lower()
    
    text = re.sub(r"don't", "do not", text)
    text = re.sub(r"don t", "do not", text)
    text = re.sub(r"didn't", "did not", text)
    text = re.sub(r"didn t", "did not", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"won t", "will not", text)
    text = re.sub(r"isn't", "is not", text)
    text = re.sub(r"isn t", "is not", text)
    text = re.sub(r"aren't", "are not", text)
    text = re.sub(r"aren t", "are not", text)
    text = re.sub(r"wasn't", "was not", text)
    text = re.sub(r"wasn t", "was not", text)
    text = re.sub(r"weren't", "were not", text)
    text = re.sub(r"weren t", "were not", text)
    text = re.sub(r"haven't", "have not", text)
    text = re.sub(r"haven t", "have not", text)
    text = re.sub(r"hadn't", "had not", text)
    text = re.sub(r"hadn t", "had not", text)
    text = re.sub(r"couldn't", "could not", text)
    text = re.sub(r"couldn t", "could not", text)
    text = re.sub(r"shouldn't", "should not", text)
    text = re.sub(r"shouldn t", "should not", text)
    text = re.sub(r"can't", "can not", text)
    text = re.sub(r"can t", "can not", text)
    text = re.sub(r"it's", "it is", text)
    text = re.sub(r"it s", "it is", text)
    text = re.sub(r"kebab", "kabab", text)
    text = re.sub(r"nun", "naan", text)
    text = re.sub(r"nan", "naan", text)
    text = re.sub('[^a-zA-Z]'," ",text)
    
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text= re.sub('\s{2,}', ' ', text)
    text = re.sub('\w*\d\w*', '', text)
#     print(text)
    text = "".join(text)
    return text

# %%
data['text']=data['text'].apply(clean_text)

# %%
data.iloc[0:16]['text']
# Out:
# 0                                 too much small amount
# 1                                  very small in amount
# 2     food average but their desert booter halwa and...
# 3                                       fresh and tasty
# 4                         everything i ordered was good
# 5     kalo jira vhorta balu vhorta not recommended b...
# 6     quantity of dal should be little more otherwis...
# 7     beef was too poor in size quantity aganist pri...
# 8     chicken was not up to the mark and lotpoti was...
# 9                      lot of sand in kali jeers bortha
# 10                                                  bad
# 11    very good food i chose this home kitchen rando...
# 12    honestly eating today s beef ribs and dal felt...
# 13    i ate good food after a long time the food was...
# 14           really good clean tasting will order again
# 15                           too spicy with dry chilli
# Name: text, dtype: object

# %%
data.iloc[111]['text']
# Out:
# 'the food was cold'

# %%
data.iloc[0]
# Out:
# Unnamed: 0                                                                   0
# ï»¿                                                                          0
# uuid                                      68e8f769-a0f0-460c-bfb9-16662fcc1e17
# createdAt                                                 2023-11-02T06:48:08Z
# updatedAt                                                 2023-11-02T06:48:08Z
# text                                                     too much small amount
# isAnonymous                                                              False
# reviewerName                                                              MOON
# reviewerId                                                            bdaclwhn
# ratings_overall                                                              2
# labels                                                                       1
# ratings                      [{'topic': 'overall', 'score': 2}, {'topic': '...
# type                                                                      user
# likeCount                                                                    0
# isLiked                                                                  False
# code                                                                      a02g
# name                                                            Mahi's Kitchen
# address                      Sector 5, road 3/A  H- 22/A, f-p6  ,fahim phar...
# city                                                                     Dhaka
# post_code                                                                 1230
# latitude                                                             23.862633
# longitude                                                             90.39168
# primary_cuisine                                                          Curry
# primary_cuisine_id                                                         195
# cuisines                      ['Curry', 'Rice Dishes', 'Bangladeshi', 'Asian']
# review_number                                                              146
# restaurant_overall_rating                                                  3.7
# hero_image                   https://images.deliveryhero.io/image/fd-bd/LH/...
# hero_listing_image           https://images.deliveryhero.io/image/fd-bd/LH/...
# vertical_type_ids                        ['restaurants', 'home_based_kitchen']
# web_path                     https://foodpanda.com.bd/restaurant/a02g/mahis...
# Name: 0, dtype: object

# %%
def get_summary(df):   

    content = data["text"].values        
    word_tok = [word.lower() for item in content for word in nltk.word_tokenize(item)]    
    st_words = set(word_tok)   
    
    fact = {
        "TotalCount": len(content),
        "TotalWords": len(word_tok),        
        "TotalUniqueWords": len(st_words),
        "MeanWordsPerTweet": len(word_tok) / len(content),
    }

    return fact, data.describe()

# %%
f, s = get_summary(data)
s
# Out:
#           Unnamed: 0            ï»¿  ratings_overall         labels  \
# count  334119.000000  334119.000000    334119.000000  334119.000000
# mean   167059.000000  168411.559947         2.817562       1.916958
# std     96451.991633   96817.799309         1.684886       0.935649
# min         0.000000       0.000000         1.000000       1.000000
# 25%     83529.500000   84763.500000         1.000000       1.000000
# 50%    167059.000000  168499.000000         3.000000       2.000000
# 75%    250588.500000  252235.500000         5.000000       3.000000
# max    334118.000000  335947.000000         5.000000       3.000000
#
#            likeCount       latitude      longitude  primary_cuisine_id  \
# count  334119.000000  334119.000000  334119.000000       334119.000000
# mean        0.241884      23.668077      90.623229          127.527136
# std         0.629411       0.528833       0.528335           54.243513
# min        -2.000000      22.269991      90.210323            0.000000
# 25%         0.000000      23.741879      90.371986           85.000000
# 50%         0.000000      23.773776      90.405709           86.000000
# 75%         0.000000      23.810406      90.425728          193.000000
# max        51.000000      24.919806      91.910593          249.000000
#
#        review_number  restaurant_overall_rating
# count  334119.000000              334119.000000
# mean     4014.909981                   3.841418
# std      5812.797803                   0.445709
# min         0.000000                   0.000000
# 25%       488.000000                   3.600000
# 50%      1584.000000                   3.900000
# 75%      4697.000000                   4.100000
# max     32993.000000                   5.000000

# %%
f
# Out:
# {'TotalCount': 334119,
#  'TotalWords': 3670563,
#  'TotalUniqueWords': 47276,
#  'MeanWordsPerTweet': 10.985795480053515}

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect=CountVectorizer()
doc=np.array(data['text'])

# %%
bag=vect.fit_transform(doc)

# %%
print(vect.vocabulary_)
# Out:
# {'too': 43554, 'much': 28883, 'small': 39646, 'amount': 1562, 'very': 45311, 'in': 19783, 'food': 15785, 'average': 2696, 'but': 6495, 'their': 42683, 'desert': 11299, 'booter': 5644, 'halwa': 18133, 'and': 1635, 'pudding': 34944, 'is': 20228, 'good': 17323, 'fresh': 16137, 'tasty': 42025, 'everything': 14417, 'ordered': 31374, 'was': 45952, 'kalo': 22188, 'jira': 21398, 'vhorta': 45428, 'balu': 3284, 'not': 30257, 'recommended': 35973, 'baki': 3196, 'shob': 38777, 'valo': 44983, 'chilo': 8037, 'quantity': 35292, 'of': 30688, 'dal': 10333, 'should': 39022, 'be': 3885, 'little': 25940, 'more': 28562, 'otherwise': 31635, 'specially': 40349, 'beef': 4006, 'poor': 33994, 'size': 39473, 'aganist': 563, 'price': 34592, 'test': 42402, 'chicken': 7852, 'up': 44612, 'to': 43349, 'the': 42644, 'mark': 27005, 'lotpoti': 26190, 'full': 16402, 'potato': 34309, 'alu': 1307, 'bhorta': 4680, 'did': 11868, 'seem': 38014, 'lot': 26176, 'sand': 37485, 'kali': 22161, 'jeers': 21091, 'bortha': 5745, 'bad': 2984, 'chose': 8467, 'this': 42888, 'home': 19007, 'kitchen': 23823, 'randomly': 35671, 'really': 35871, 'got': 17506, 'packaging': 31981, 'please': 33702, 'always': 1352, 'maintain': 26562, 'same': 37431, 'standard': 40636, 'allah': 1165, 'bless': 5173, 'you': 46990, 'with': 46396, 'all': 1160, 'sucess': 41054, 'honestly': 19032, 'eating': 13399, 'today': 43375, 'ribs': 36609, 'felt': 15299, 'like': 25801, 'my': 29150, 'own': 31854, 'no': 30081, 'extra': 14710, 'colors': 9129, 'or': 31330, 'anything': 1795, 'else': 13913, 'nice': 29819, 'homemade': 19017, 'it': 20526, 'would': 46599, 'great': 17636, 'if': 19581, 'could': 9703, 'do': 12641, 'sooner': 40112, 'ate': 2506, 'after': 535, 'long': 26110, 'time': 43209, 'fun': 16422, 'only': 31124, 'give': 17098, 'so': 39783, 'suggestion': 41127, 'increase': 19836, 'some': 39983, 'out': 31694, 'delivered': 11123, 'faster': 15076, 'clean': 8860, 'tasting': 42014, 'will': 46329, 'order': 31363, 'again': 552, 'spicy': 40415, 'dry': 13060, 'chilli': 8016, 'quality': 35263, 'now': 30360, 'absolutely': 164, 'delicious': 11073, 'fish': 15518, 'fourth': 16024, 'its': 20572, 'displayed': 12329, 'at': 2491, 'photo': 33294, 'cold': 9061, 'shutki': 39199, 'dherosh': 11594, 'bhaji': 4487, 'lal': 25328, 'shak': 38340, 'boil': 5341, 'mone': 28438, 'hocchilo': 18775, 'bhaja': 4481, 'hoini': 18884, 'rui': 37091, 'curry': 10105, 'kom': 24145, 'ta': 41526, 'arektu': 2064, 'howa': 19202, 'uchit': 44121, 'bot': 5787, 'tender': 42328, 'delivery': 11139, 'person': 33168, 'comparing': 9255, 'teast': 42157, 'thanks': 42603, 'egg': 13528, 'fry': 16299, 'dey': 11455, 'nai': 29313, 'pura': 35027, 'kacha': 21945, 'worst': 46555, 'best': 4327, 'foods': 15865, 'yummy': 47093, 'keep': 22535, 'pieces': 33400, 'uttara': 44773, 'aro': 2118, 'koyekta': 24785, 'item': 20544, 'barate': 3516, 'paren': 32440, 'taste': 41963, 'extremely': 14732, 'high': 18612, 'while': 46244, 'ordering': 31387, 'told': 43477, 'them': 42719, 'make': 26615, 'less': 25653, 'they': 42776, 'listen': 25904, 'me': 27316, 'disappointing': 12144, 'as': 2176, 'expectation': 14595, 'your': 46999, 'service': 38202, 'has': 18303, 'become': 3978, 'utterly': 44783, 'nowadays': 30362, 'tk': 43296, 'worth': 46578, 'rice': 36611, 'spilled': 40433, 'went': 46149, 'waste': 46002, 'lost': 26174, 'regular': 36138, 'customer': 10133, 'match': 27159, 'kaljira': 22177, 'bharta': 4547, 'arrive': 2152, 'usual': 44738, 'neat': 29563, 'presentation': 34543, 'portion': 34228, 'decreased': 10746, 'tiny': 43250, 'box': 5855, 'orders': 31408, 'from': 16245, 'are': 2030, 'daal': 10209, 'payesh': 32893, 'on': 30983, 'boxes': 5861, 'abominable': 133, 'thing': 42860, 'rupees': 37130, 'wasted': 46005, 'one': 31008, 'these': 42756, 'junk': 21775, 'made': 26459, 'think': 42865, 'sufficient': 41100, 'comparison': 9256, 'palong': 32218, 'off': 30693, 'thank': 42596, 'even': 14373, 'cutney': 10171, 'complementary': 9301, 'here': 18548, 'couple': 9732, 'times': 43222, 'll': 25964, 'there': 42742, 'pcs' ...

# %%
print(len(vect.vocabulary_))
# Out:
# 47253

# %%
# print(bag.toarray())

# %%
r=np.array(data['text'].values).reshape(-1,1)

# %%
r.shape
# Out:
# (334119, 1)

# %% [markdown]
# # Bag_of_words

# %% [markdown]
# from sklearn.feature_extraction.text import CountVectorizer
# bow_vectorizer = CountVectorizer(max_df=0.90, min_df=2, max_features=20000, stop_words=None)
# bow = bow_vectorizer.fit_transform(df['text'])
# bow.shape

# %% [markdown]
# # TF-IDF Vectorizer

# %%
from sklearn.feature_extraction.text import TfidfTransformer, TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer( )
tfidf = tfidf_vectorizer.fit_transform(data['text'])
tfidf.shape
# Out:
# (334119, 47253)

# %% [markdown]
# tfidf

# %% [markdown]
# # Train_test_split

# %%
y=data['ratings_overall'].values
X_train, X_test, Y_train, Y_test = train_test_split(tfidf, y, test_size=0.25, random_state=42)
print("Size of X_train", (X_train.shape))
print("Size of Y_train", (Y_train.shape))
print("Size of X_test", (X_test.shape))
print("Size of Y_test", (Y_test.shape))
# Out:
# Size of X_train (250589, 47253)
# Size of Y_train (250589,)
# Size of X_test (83530, 47253)
# Size of Y_test (83530,)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(max_depth=None, min_samples_split=42, min_samples_leaf=1, random_state=42)
dt = dt.fit(X_train, Y_train)
score = dt.score(X_test, Y_test)

print("Accuracy:", score)
# Out:
# Accuracy: 0.5908416137914522

# %%
from sklearn.metrics import precision_score,recall_score, confusion_matrix, classification_report,accuracy_score, f1_score
from sklearn.metrics import confusion_matrix
import seaborn as sns

pred_y = dt.predict(X_test)
pred_y = list(pred_y.flatten())
pred_y = np.round(pred_y)

print('Accuracy:', accuracy_score(Y_test, pred_y))
# print('F1 score:', f1_score(Y_test, pred_y))
# print('Recall:', recall_score(Y_test, pred_y))
# print('Precision:', precision_score(Y_test, pred_y))
print('\n Clasification report:\n', classification_report(Y_test,pred_y,digits=4))
# Out:
# Accuracy: 0.5908416137914522
#
#  Clasification report:
#                precision    recall  f1-score   support
#
#            1     0.6930    0.7770    0.7326     31832
#            2     0.1994    0.1499    0.1712      8450
#            3     0.2786    0.2454    0.2609      9851
#            4     0.2976    0.2137    0.2488      9728
#            5     0.7301    0.7967    0.7620     23669
#
#     accuracy                         0.5908     83530
#    macro avg     0.4398    0.4365    0.4351     83530
# weighted avg     0.5587    0.5908    0.5722     83530

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Assuming y_true and y_pred are your true and predicted labels
cm = confusion_matrix(Y_test, pred_y)

# Create a heatmap
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
cm = confusion_matrix(Y_test, pred_y) 
classes = np.array([1,2,3,4,5])


cm_df = pd.DataFrame(cm,index = classes,columns = classes)

plt.figure(figsize=(10,5))
sns.heatmap(cm_df, annot=True, cmap="YlGnBu", fmt='g')
plt.title(f'Confusion Matrix for Decision Tree')
# plt.title(f'Shallow Neural Network\nAccuracy: {acc}')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# plt.savefig(f'ann.png',dpi = 600,bbox_inches = 'tight')
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'font.size': 14})
plt.show()
print(cm_df)
# Out:
#        1     2     3     4      5
# 1  24732  2883  2215   765   1237
# 2   4528  1267  1485   624    546
# 3   3476  1206  2417  1423   1329
# 4   1506   621  1662  2079   3860
# 5   1445   377   895  2094  18858

# %%
sns.__version__
# Out:
# '0.13.0'

# %%
pip install -q scikit-plot
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import scikitplot as skplt

skplt.metrics.plot_confusion_matrix(
   Y_test, pred_y,
    figsize=(12,12))
# Out:
# <Axes: title={'center': 'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver='liblinear')
lr=lr.fit(X_train, Y_train)
score = lr.score(X_test, Y_test)

print("Accuracy:", score)
# Out:
# Accuracy: 0.6593439482820543

# %%
from sklearn.metrics import precision_score,recall_score, confusion_matrix, classification_report,accuracy_score, f1_score
from sklearn.metrics import confusion_matrix
import seaborn as sns

pred_y = lr.predict(X_test)
pred_y = list(pred_y.flatten())
pred_y = np.round(pred_y)

print('Accuracy:', accuracy_score(Y_test, pred_y))
# print('F1 score:', f1_score(Y_test, pred_y))
# print('Recall:', recall_score(Y_test, pred_y))
# print('Precision:', precision_score(Y_test, pred_y))
print('\n Clasification report:\n', classification_report(Y_test,pred_y,digits=4))
# Out:
# Accuracy: 0.6593439482820543
#
#  Clasification report:
#                precision    recall  f1-score   support
#
#            1     0.6793    0.9305    0.7853     31832
#            2     0.2981    0.0363    0.0648      8450
#            3     0.3711    0.2175    0.2743      9851
#            4     0.4001    0.2079    0.2736      9728
#            5     0.7475    0.8865    0.8111     23669
#
#     accuracy                         0.6593     83530
#    macro avg     0.4992    0.4557    0.4418     83530
# weighted avg     0.5912    0.6593    0.5999     83530

# %%
cm = confusion_matrix(Y_test, pred_y) 
classes = np.array([1,2,3,4,5])


cm_df = pd.DataFrame(cm,index = classes,columns = classes)

plt.figure(figsize=(10,5))
sns.heatmap(cm_df, annot=True, cmap="YlGnBu", fmt='g')
plt.title(f'Confusion Matrix for Logistic Regression')
# plt.title(f'Shallow Neural Network\nAccuracy: {acc}')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# plt.savefig(f'ann.png',dpi = 600,bbox_inches = 'tight')
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'font.size': 14})
plt.show()

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
 
rf= RandomForestClassifier( max_depth=60, random_state=42)
rf = rf.fit(X_train, Y_train)
score = rf.score(X_test, Y_test)
print("Accuracy:", score)
# Out:
# Accuracy: 0.6073865677002275

# %%
from sklearn.metrics import precision_score,recall_score, confusion_matrix, classification_report,accuracy_score, f1_score
from sklearn.metrics import confusion_matrix
import seaborn as sns

pred_y = rf.predict(X_test)
pred_y = list(pred_y.flatten())
pred_y = np.round(pred_y)

print('Accuracy:', accuracy_score(Y_test, pred_y))
# print('F1 score:', f1_score(Y_test, pred_y))
# print('Recall:', recall_score(Y_test, pred_y))
# print('Precision:', precision_score(Y_test, pred_y))
print('\n Clasification report:\n', classification_report(Y_test,pred_y,digits=4))
# Out:
# Accuracy: 0.6073865677002275
#
#  Clasification report:
#                precision    recall  f1-score   support
#
#            1     0.5728    0.9555    0.7162     31832
#            2     0.0000    0.0000    0.0000      8450
#            3     0.4531    0.0059    0.0116      9851
#            4     0.4957    0.0357    0.0666      9728
#            5     0.6727    0.8414    0.7477     23669
#
#     accuracy                         0.6074     83530
#    macro avg     0.4389    0.3677    0.3084     83530
# weighted avg     0.5201    0.6074    0.4939     83530

# %%
cm = confusion_matrix(Y_test, pred_y) 
classes = np.array([1,2,3,4,5])


cm_df = pd.DataFrame(cm,index = classes,columns = classes)

plt.figure(figsize=(10,5))
sns.heatmap(cm_df, annot=True, cmap="YlGnBu", fmt='g')
plt.title(f'Confusion Matrix for Random Forest')
# plt.title(f'Shallow Neural Network\nAccuracy: {acc}')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# plt.savefig(f'ann.png',dpi = 600,bbox_inches = 'tight')
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'font.size': 14})
plt.show()

# %% [markdown]
# # SVM

# %%
from sklearn.calibration import CalibratedClassifierCV
from sklearn.svm import LinearSVC
svm = LinearSVC()
sv= CalibratedClassifierCV(svm) 
sv = sv.fit(X_train, Y_train)  
score =sv.score(X_test, Y_test)
print("Accuracy:", score)
# Out:
# Accuracy: 0.6537052555967916

# %%
from sklearn.metrics import precision_score,recall_score, confusion_matrix, classification_report,accuracy_score, f1_score
from sklearn.metrics import confusion_matrix
import seaborn as sns

pred_y = sv.predict(X_test)
pred_y = list(pred_y.flatten())
pred_y = np.round(pred_y)

print('Accuracy:', accuracy_score(Y_test, pred_y))
# print('F1 score:', f1_score(Y_test, pred_y))
# print('Recall:', recall_score(Y_test, pred_y))
# print('Precision:', precision_score(Y_test, pred_y))
print('\n Clasification report:\n', classification_report(Y_test,pred_y,digits=4))
# Out:
# Accuracy: 0.6537052555967916
#
#  Clasification report:
#                precision    recall  f1-score   support
#
#            1     0.6773    0.9225    0.7811     31832
#            2     0.2630    0.0394    0.0685      8450
#            3     0.3637    0.1992    0.2574      9851
#            4     0.3752    0.2240    0.2805      9728
#            5     0.7496    0.8773    0.8084     23669
#
#     accuracy                         0.6537     83530
#    macro avg     0.4858    0.4525    0.4392     83530
# weighted avg     0.5837    0.6537    0.5967     83530

# %%
cm = confusion_matrix(Y_test, pred_y) 
classes = np.array([1,2,3,4,5])


cm_df = pd.DataFrame(cm,index = classes,columns = classes)

plt.figure(figsize=(10,5))
sns.heatmap(cm_df, annot=True, cmap="YlGnBu", fmt='g')
plt.title(f'Confusion Matrix for SVM')
# plt.title(f'Shallow Neural Network\nAccuracy: {acc}')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# plt.savefig(f'ann.png',dpi = 600,bbox_inches = 'tight')
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'font.size': 14})
plt.show()

# %% [markdown]
# # Naive Bayes

# %%
from sklearn import model_selection, naive_bayes, svm
nb = naive_bayes.MultinomialNB(alpha=0.1)
nb = nb.fit(X_train, Y_train) 
score = nb.score(X_test, Y_test)
print("Accuracy:", score)
# Out:
# Accuracy: 0.6338321561115767

# %%
from sklearn.metrics import precision_score,recall_score, confusion_matrix, classification_report,accuracy_score, f1_score
from sklearn.metrics import confusion_matrix
import seaborn as sns

pred_y = nb.predict(X_test)
pred_y = list(pred_y.flatten())
pred_y = np.round(pred_y)

print('Accuracy:', accuracy_score(Y_test, pred_y))
# print('F1 score:', f1_score(Y_test, pred_y))
# print('Recall:', recall_score(Y_test, pred_y))
# print('Precision:', precision_score(Y_test, pred_y))
print('\n Clasification report:\n', classification_report(Y_test,pred_y,digits=4))
# Out:
# Accuracy: 0.6338321561115767
#
#  Clasification report:
#                precision    recall  f1-score   support
#
#            1     0.6311    0.9288    0.7516     31832
#            2     0.2355    0.0196    0.0363      8450
#            3     0.3549    0.1712    0.2309      9851
#            4     0.3831    0.1721    0.2375      9728
#            5     0.7391    0.8387    0.7858     23669
#
#     accuracy                         0.6338     83530
#    macro avg     0.4687    0.4261    0.4084     83530
# weighted avg     0.5602    0.6338    0.5676     83530

# %%
cm = confusion_matrix(Y_test, pred_y) 
classes = np.array([1,2,3,4,5])


cm_df = pd.DataFrame(cm,index = classes,columns = classes)

plt.figure(figsize=(10,5))
sns.heatmap(cm_df, annot=True, cmap="YlGnBu", fmt='g')
plt.title(f'Confusion Matrix for Naive Bayes')
# plt.title(f'Shallow Neural Network\nAccuracy: {acc}')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# plt.savefig(f'ann.png',dpi = 600,bbox_inches = 'tight')
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'font.size': 14})
plt.show()

# %% [markdown]
# # XGBClassifier

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
Y_train = le.fit_transform(Y_train)
Y_test = le.fit_transform(Y_test)

# %%
import xgboost as xgb
model = xgb.XGBClassifier()

#Training the model on the training data
xg=model.fit(X_train, Y_train) 
score = xg.score(X_test, Y_test)
print("Accuracy:", score)
# Out:
# Accuracy: 0.6434933556805938

# %%
from sklearn.metrics import precision_score,recall_score, confusion_matrix, classification_report,accuracy_score, f1_score
from sklearn.metrics import confusion_matrix
import seaborn as sns

pred_y = xg.predict(X_test)
pred_y = list(pred_y.flatten())
pred_y = np.round(pred_y)

print('Accuracy:', accuracy_score(Y_test, pred_y))
# print('F1 score:', f1_score(Y_test, pred_y))
# print('Recall:', recall_score(Y_test, pred_y))
# print('Precision:', precision_score(Y_test, pred_y))
print('\n Clasification report:\n', classification_report(Y_test,pred_y,digits=4))
# Out:
# Accuracy: 0.6434933556805938
#
#  Clasification report:
#                precision    recall  f1-score   support
#
#            0     0.6375    0.9505    0.7632     31832
#            1     0.2877    0.0276    0.0503      8450
#            2     0.3763    0.1602    0.2247      9851
#            3     0.3960    0.2190    0.2820      9728
#            4     0.7611    0.8262    0.7923     23669
#
#     accuracy                         0.6435     83530
#    macro avg     0.4917    0.4367    0.4225     83530
# weighted avg     0.5782    0.6435    0.5798     83530

# %%
cm = confusion_matrix(Y_test, pred_y) 
classes = np.array([1,2,3,4,5])


cm_df = pd.DataFrame(cm,index = classes,columns = classes)

plt.figure(figsize=(10,5))
sns.heatmap(cm_df, annot=True, cmap="YlGnBu", fmt='g')
plt.title(f'Confusion Matrix for XGboost')
# plt.title(f'Shallow Neural Network\nAccuracy: {acc}')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# plt.savefig(f'ann.png',dpi = 600,bbox_inches = 'tight')
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'font.size': 14})
plt.show()

# %% [markdown]
# # KNN classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

model= KNeighborsClassifier(n_neighbors=10)
knn=model.fit(X_train, Y_train) 
score = knn.score(X_test, Y_test)

print("Accuracy:", score)
# Out:
# Accuracy: 0.4467616425236442

# %%
from sklearn.metrics import precision_score,recall_score, confusion_matrix, classification_report,accuracy_score, f1_score
from sklearn.metrics import confusion_matrix
import seaborn as sns

pred_y = knn.predict(X_test)
pred_y = list(pred_y.flatten())
pred_y = np.round(pred_y)

print('Accuracy:', accuracy_score(Y_test, pred_y))
# print('F1 score:', f1_score(Y_test, pred_y))
# print('Recall:', recall_score(Y_test, pred_y))
# print('Precision:', precision_score(Y_test, pred_y))
print('\n Clasification report:\n', classification_report(Y_test,pred_y,digits=4))
# Out:
# Accuracy: 0.4467616425236442
#
#  Clasification report:
#                precision    recall  f1-score   support
#
#            0     0.6657    0.4629    0.5460     31832
#            1     0.2144    0.0528    0.0847      8450
#            2     0.1479    0.4952    0.2278      9851
#            3     0.3012    0.1419    0.1929      9728
#            4     0.7297    0.6709    0.6991     23669
#
#     accuracy                         0.4468     83530
#    macro avg     0.4118    0.3647    0.3501     83530
# weighted avg     0.5347    0.4468    0.4641     83530

# %%
cm = confusion_matrix(Y_test, pred_y) 
classes = np.array([1,2,3,4,5])


cm_df = pd.DataFrame(cm,index = classes,columns = classes)

plt.figure(figsize=(10,5))
sns.heatmap(cm_df, annot=True, cmap="YlGnBu", fmt='g')
plt.title(f'Confusion Matrix for KNN')
# plt.title(f'Shallow Neural Network\nAccuracy: {acc}')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# plt.savefig(f'ann.png',dpi = 600,bbox_inches = 'tight')
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'font.size': 14})
plt.show()
